# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.h_volatility_forrest import forest_mse_train, forest_mse_test, forest_r2_train, forest_r2_test, y_test, forest_fit, X_test

# %%
print(f"Results of Random Forest:\nmse_train: {forest_mse_train}\nmse_test: {forest_mse_test}\nr2_train: {forest_r2_train}\nr2_test: {forest_r2_test}")
# Out:
# Results of Random Forest:
# mse_train: 2.3618904418768282e-08
# mse_test: 2.0291066125388975e-08
# r2_train: 0.6859129977844158
# r2_test: -4.349779590668786

# %%
plt.plot(forest_fit.predict(X_test))
plt.plot(np.array(y_test))
plt.show()
