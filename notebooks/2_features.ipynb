# %%
import matplotlib.pyplot as plt
import numpy as np
from src.a_lag_features import returns_lagger, sp

# %%
# showing an example of lagged features
returns_lagger(sp,4)
# Out:
#        returns     lag_1     lag_2     lag_3     lag_4
# 16    0.015985  0.005977 -0.006871  0.004201 -0.012108
# 17   -0.001543  0.015985  0.005977 -0.006871  0.004201
# 18    0.002781 -0.001543  0.015985  0.005977 -0.006871
# 19   -0.004437  0.002781 -0.001543  0.015985  0.005977
# 20    0.010878 -0.004437  0.002781 -0.001543  0.015985
# ...        ...       ...       ...       ...       ...
# 1251  0.011729  0.008139  0.005912 -0.005213 -0.000015
# 1252  0.002652  0.011729  0.008139  0.005912 -0.005213
# 1253  0.000480  0.002652  0.011729  0.008139  0.005912
# 1254 -0.011059  0.000480  0.002652  0.011729  0.008139
# 1255  0.003275 -0.011059  0.000480  0.002652  0.011729
#
# [1240 rows x 5 columns]

# %%
# some information
returns_lagger(sp,4).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1240 entries, 16 to 1255
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   returns  1240 non-null   float64
#  1   lag_1    1240 non-null   float64
#  2   lag_2    1240 non-null   float64
#  3   lag_3    1240 non-null   float64
#  4   lag_4    1240 non-null   float64
# dtypes: float64(5)
# memory usage: 48.6 KB

# %%
# already showed this plot in the previous notebook, but it doesn't hurt to have it here
plt.plot(np.linspace(16,1255,1240),returns_lagger(sp,4)["returns"])
plt.title("Logarithmic Returns")
plt.show()

# %%
returns_lagger(sp,9)
# Out:
#        returns     lag_1     lag_2     lag_3     lag_4     lag_5     lag_6  \
# 16    0.015985  0.005977 -0.006871  0.004201 -0.012108 -0.005393  0.012405
# 17   -0.001543  0.015985  0.005977 -0.006871  0.004201 -0.012108 -0.005393
# 18    0.002781 -0.001543  0.015985  0.005977 -0.006871  0.004201 -0.012108
# 19   -0.004437  0.002781 -0.001543  0.015985  0.005977 -0.006871  0.004201
# 20    0.010878 -0.004437  0.002781 -0.001543  0.015985  0.005977 -0.006871
# ...        ...       ...       ...       ...       ...       ...       ...
# 1251  0.011729  0.008139  0.005912 -0.005213 -0.000015  0.010347  0.005660
# 1252  0.002652  0.011729  0.008139  0.005912 -0.005213 -0.000015  0.010347
# 1253  0.000480  0.002652  0.011729  0.008139  0.005912 -0.005213 -0.000015
# 1254 -0.011059  0.000480  0.002652  0.011729  0.008139  0.005912 -0.005213
# 1255  0.003275 -0.011059  0.000480  0.002652  0.011729  0.008139  0.005912
#
#          lag_7     lag_8     lag_9
# ...

# %%
returns_lagger(sp,15)
# Out:
#        returns     lag_1     lag_2     lag_3     lag_4     lag_5     lag_6  \
# 16    0.015985  0.005977 -0.006871  0.004201 -0.012108 -0.005393  0.012405
# 17   -0.001543  0.015985  0.005977 -0.006871  0.004201 -0.012108 -0.005393
# 18    0.002781 -0.001543  0.015985  0.005977 -0.006871  0.004201 -0.012108
# 19   -0.004437  0.002781 -0.001543  0.015985  0.005977 -0.006871  0.004201
# 20    0.010878 -0.004437  0.002781 -0.001543  0.015985  0.005977 -0.006871
# ...        ...       ...       ...       ...       ...       ...       ...
# 1251  0.011729  0.008139  0.005912 -0.005213 -0.000015  0.010347  0.005660
# 1252  0.002652  0.011729  0.008139  0.005912 -0.005213 -0.000015  0.010347
# 1253  0.000480  0.002652  0.011729  0.008139  0.005912 -0.005213 -0.000015
# 1254 -0.011059  0.000480  0.002652  0.011729  0.008139  0.005912 -0.005213
# 1255  0.003275 -0.011059  0.000480  0.002652  0.011729  0.008139  0.005912
#
# ...

# %%
plt.hist(returns_lagger(sp,1)["returns"])
# Out:
# (array([  4.,  13., 106., 679., 402.,  34.,   0.,   1.,   0.,   1.]),
#  array([-0.06032655, -0.04430761, -0.02828867, -0.01226973,  0.0037492 ,
#          0.01976814,  0.03578708,  0.05180602,  0.06782496,  0.0838439 ,
#          0.09986283]),
#  <BarContainer object of 10 artists>)

# %%
# no idea if this is useful, just exploring data: in the ML model(s) the labels (output) will depend on all the features (which themselves are just the returns, but shifted)
plt.plot(returns_lagger(sp,9)["lag_9"],returns_lagger(sp,1)["returns"])
