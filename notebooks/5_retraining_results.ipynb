# %%
import matplotlib.pyplot as plt

# %%
from src.retraining import mse_5_retrain, fit_5_new, labels_retrain,feat_5_retrain, r2_5_retrain

# %%
# just confirming that the features are sliced correctly
feat_5_retrain
# Out:
#          lag_1     lag_2     lag_3     lag_4     lag_5
# 16    0.005977 -0.006871  0.004201 -0.012108 -0.005393
# 17    0.015985  0.005977 -0.006871  0.004201 -0.012108
# 18   -0.001543  0.015985  0.005977 -0.006871  0.004201
# 19    0.002781 -0.001543  0.015985  0.005977 -0.006871
# 20   -0.004437  0.002781 -0.001543  0.015985  0.005977
# ...        ...       ...       ...       ...       ...
# 1127  0.006280  0.000381  0.007199  0.020830  0.015377
# 1128  0.000397  0.006280  0.000381  0.007199  0.020830
# 1129  0.007062  0.000397  0.006280  0.000381  0.007199
# 1130  0.014735  0.007062  0.000397  0.006280  0.000381
# 1131 -0.005751  0.014735  0.007062  0.000397  0.006280
#
# [1116 rows x 5 columns]

# %%
labels_retrain
# Out:
# 16      0.015985
# 17     -0.001543
# 18      0.002781
# 19     -0.004437
# 20      0.010878
#           ...
# 1127    0.000397
# 1128    0.007062
# 1129    0.014735
# 1130   -0.005751
# 1131   -0.008393
# Name: returns, Length: 1116, dtype: float64

# %%
plt.plot(labels_retrain)
plt.plot(fit_5_new.predict(feat_5_retrain))
plt.show()

# %%
print(f"mse_5_retrain:\n{mse_5_retrain}\nr2_5_retrain: {r2_5_retrain}")
# Out:
# mse_5_retrain:
# 0.00012315183240854598
# r2_5_retrain: 0.006450925702478849
