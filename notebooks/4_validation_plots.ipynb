# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
from src.c_validation import fit_2, df_2, labels

plt.plot(fit_2.predict(df_2),label='pred_2')
plt.plot(labels[992:1116],label='labels')
plt.legend()
plt.show()
df_2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1008 to 1131
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
# dtypes: float64(2)
# memory usage: 2.1 KB

# %%
from src.c_validation import fit_3, df_3
plt.plot(fit_3.predict(df_3),label='pred_3')
plt.plot(labels[992:1116],label='labels')
plt.legend()
plt.show()
df_3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1008 to 1131
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
#  2   lag_3   124 non-null    float64
# dtypes: float64(3)
# memory usage: 3.0 KB

# %%
from src.c_validation import fit_5, df_5
plt.plot(fit_5.predict(df_5),label='pred_5')
plt.plot(labels[992:1116],label='labels')
plt.legend()
plt.show()
df_5.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1008 to 1131
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
#  2   lag_3   124 non-null    float64
#  3   lag_4   124 non-null    float64
#  4   lag_5   124 non-null    float64
# dtypes: float64(5)
# memory usage: 5.0 KB

# %%
from src.c_validation import fit_7, df_7
plt.plot(fit_7.predict(df_7),label='pred_7')
plt.plot(labels[992:1116],label='labels')
plt.legend()
plt.show()
df_7.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1008 to 1131
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
#  2   lag_3   124 non-null    float64
#  3   lag_4   124 non-null    float64
#  4   lag_5   124 non-null    float64
#  5   lag_6   124 non-null    float64
#  6   lag_7   124 non-null    float64
# dtypes: float64(7)
# memory usage: 6.9 KB

# %%
from src.c_validation import fit_11, df_11
plt.plot(fit_11.predict(df_11),label='pred_11')
plt.plot(labels[992:1116],label='labels')
plt.legend()
plt.show()
df_11.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1008 to 1131
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
#  2   lag_3   124 non-null    float64
#  3   lag_4   124 non-null    float64
#  4   lag_5   124 non-null    float64
#  5   lag_6   124 non-null    float64
#  6   lag_7   124 non-null    float64
#  7   lag_8   124 non-null    float64
#  8   lag_9   124 non-null    float64
#  9   lag_10  124 non-null    float64
#  10  lag_11  124 non-null    float64
# dtypes: float64(11)
# memory usage: 10.8 KB

# %%
from src.c_validation import fit_15, df_15
plt.plot(fit_15.predict(df_15),label='pred_15')
plt.plot(labels[992:1116],label='labels')
plt.legend()
plt.show()
df_15.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1008 to 1131
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
#  2   lag_3   124 non-null    float64
#  3   lag_4   124 non-null    float64
#  4   lag_5   124 non-null    float64
#  5   lag_6   124 non-null    float64
#  6   lag_7   124 non-null    float64
#  7   lag_8   124 non-null    float64
#  8   lag_9   124 non-null    float64
#  9   lag_10  124 non-null    float64
#  10  lag_11  124 non-null    float64
#  11  lag_12  124 non-null    float64
#  12  lag_13  124 non-null    float64
#  13  lag_14  124 non-null    float64
#  14  lag_15  124 non-null    float64
# dtypes: float64(15)
# memory usage: 14.7 KB

# %%
# mean squared error and r square score on the validation test
from src.c_validation import mse_2_val, mse_3_val, mse_5_val, mse_7_val, mse_11_val, mse_15_val
print(f"mse_2_val: {mse_2_val}\nmse_3_val: {mse_3_val}\nmse_5_val: {mse_5_val}\nmse_7_val: {mse_7_val}\nmse_11_val: {mse_11_val}\nmse_15_val: {mse_15_val}")
print(f"r2_2: {r2_score(labels[992:1116], fit_2.predict(df_2))}\nr2_3: {r2_score(labels[992:1116],fit_3.predict(df_3))}\nr2_5: {r2_score(labels[992:1116],fit_5.predict(df_5))}\nr2_7: {r2_score(labels[992:1116],fit_7.predict(df_7))}\nr2_11: {r2_score(labels[992:1116],fit_11.predict(df_11))}\nr2_15: {r2_score(labels[992:1116],fit_15.predict(df_15))}")
# Out:
# mse_2_val: 0.00025336930547826414
# mse_3_val: 0.00025090380979842555
# mse_5_val: 0.0002508051033025137
# mse_7_val: 0.00025201486965832794
# mse_11_val: 0.00025789092386182226
# mse_15_val: 0.0002592820095214613
# r2_2: -0.016649567770948837
# r2_3: -0.006756715467795438
# r2_5: -0.006360653615647971
# r2_7: -0.011214866087915887
# r2_11: -0.03479265486112482
# r2_15: -0.040374414782417656

# %%
# the winner is lag-5: smallest mse and biggest r**2
