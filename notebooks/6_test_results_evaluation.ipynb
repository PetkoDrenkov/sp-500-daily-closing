# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.e_test import mse_test, r2_score_test, fit_5_new, labels_test, feat_5_test, rms_test

# %%
plt.plot(fit_5_new.predict(feat_5_test))
plt.plot(np.array(labels_test))
plt.show()

# %%
print(f"{feat_5_test.info()},\n{labels_test.info()}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 1132 to 1255
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lag_1   124 non-null    float64
#  1   lag_2   124 non-null    float64
#  2   lag_3   124 non-null    float64
#  3   lag_4   124 non-null    float64
#  4   lag_5   124 non-null    float64
# dtypes: float64(5)
# memory usage: 5.0 KB
# <class 'pandas.Series'>
# RangeIndex: 124 entries, 1132 to 1255
# Series name: returns
# Non-Null Count  Dtype
# --------------  -----
# 124 non-null    float64
# dtypes: float64(1)
# memory usage: 1.1 KB
# None,
# None

# %%
# positive r2 (r-squared) score suggests predictive capability
print(f"mse: {mse_test}\nrms_test: {rms_test}\nr2_score: {r2_score_test}")
# Out:
# mse: 5.20020658206141e-05
# rms_test: 0.007211245788392883
# r2_score: -0.0253521931414169

# %%
# mean directional accuracy above o.5 suggests predictive capability
mda = np.mean(np.sign(labels_test) == np.sign(fit_5_new.predict(feat_5_test)))
print(f"mda: {mda}")
# Out:
# mda: 0.5
