# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.f_volatility_lin_reg import mse_train, mse_test, r2_train, r2_test, y_test, fit, X_test

# %%
print(f"Results of Linear Regression:\nmse_train: {mse_train}\nmse_test: {mse_test}\nr2_train: {r2_train}\nr2_test: {r2_test}")
# Out:
# Results of Linear Regression:
# mse_train: 1.3016003899739223e-07
# mse_test: 1.941984321458129e-08
# r2_train: 0.12944993555656714
# r2_test: -0.18892325699671897

# %%
plt.plot(fit.predict(X_test))
plt.plot(np.array(y_test))
plt.show()

# %%
from src.g_volatility_tree import tree_mse_train, tree_mse_test, tree_r2_train, tree_r2_test, y_test, tree_fit, X_test

# %%
print(f"Results of Decision Tree Regressor:\nmse_train: {tree_mse_train}\nmse_test: {tree_mse_test}\nr2_train: {tree_r2_train}\nr2_test: {tree_r2_test}")
# Out:
# Results of Decision Tree Regressor:
# mse_train: 1.1394191624112496e-18
# mse_test: 4.4155109851373514e-08
# r2_train: 0.9999999999923792
# r2_test: -1.7032678089865199

# %%
plt.plot(tree_fit.predict(X_test))
plt.plot(np.array(y_test))
plt.show()
