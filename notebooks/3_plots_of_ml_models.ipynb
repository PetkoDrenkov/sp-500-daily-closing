# %%
from src.b_training_models import predict_2, predict_3, predict_5, predict_7, predict_11, predict_15,labels
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# plot of the first model prediction
plt.plot(np.linspace(16,1007,992),predict_2,label="Lin_Reg_Lag_2")
plt.plot(np.linspace(16,1007,992),labels[:992],label="Actual_Data",alpha=0.5)
plt.legend()
plt.show()

# %%
# increasing the lag depth seems to bring a little bit more optimistic results
plt.plot(np.linspace(16,1007,992),predict_3,label="Lin_Reg_Lag_3")
plt.plot(np.linspace(16,1007,992),labels[:992],label="Actual_Data",alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(np.linspace(16,1007,992),predict_5,label="Lin_Reg_Lag_5")
plt.plot(np.linspace(16,1007,992),labels[:992],label="Actual_Data",alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(np.linspace(16,1007,992),predict_7,label="Lin_Reg_Lag_7")
plt.plot(np.linspace(16,1007,992),labels[:992],label="Actual_Data",alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(np.linspace(16,1007,992),predict_11,label="Lin_Reg_Lag_11")
plt.plot(np.linspace(16,1007,992),labels[:992],label="Actual_Data",alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(np.linspace(16,1007,992),predict_15,label="Lin_Reg_Lag_15",alpha=0.5)
plt.plot(np.linspace(16,1007,992),labels[:992],label="Actual_Data",alpha=0.5)
plt.legend()
plt.show()

# %%
# comparison between the deepest lag and the most shallow one
plt.plot(np.linspace(16,1007,992),predict_2,label="Lin_Reg_Lag_2",alpha=0.5)
plt.plot(np.linspace(16,1007,992),predict_15,label="Lin_Reg_Lag_15",alpha=0.5)
plt.legend()
plt.show()
